# %%
import matplotlib.pylab as plt
import seaborn as sns

#%matplotlib inline


file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numbers10.txt")



numbers = []
x1 = []
u1 = []
v1 = [] 

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    x1.append(row[0])
    u1.append(row[1])
    v1.append(row[2])

# %%
file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numbers100.txt")

numbers = []
x2 = []
u2 = []
v2 = [] 

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    x2.append(row[0])
    u2.append(row[1])
    v2.append(row[2])

# %%
file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numbers1000.txt")

numbers = []
x3 = []
u3 = []
v3 = []

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    x3.append(row[0])
    u3.append(row[1])
    v3.append(row[2])

# %%
file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numberslu10.txt")


numbers = []
v12 = [0.0] 

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    v12.append(row[0])

v12.append(0.0)

# %%
file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numberslu100.txt")


numbers = []
v22 = [0.0] 

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    v22.append(row[0])

v22.append(0.0)

# %%
file = open("/home/johannes/Work/FYS3150/qt creator/build-Project1-Desktop_Qt_5_7_0_GCC_64bit-Debug/numberslu1000.txt")


numbers = []
v32 = [0.0] 

for line in file:
    numbers.append([float(i) for i in line.split()])
    
for row in numbers:
    v32.append(row[0])

v32.append(0.0)

# %%
f, axarr = plt.subplots(3, sharex = True)
plt.xlabel('x')

line1, = axarr[0].plot(x1, u1, label = 'Exact solution')
line2, = axarr[0].plot(x1, v1, label = 'Tridiagonal solver')
line3, = axarr[0].plot(x1, v12, label = 'LU decompositon')
axarr[0].legend(handles = [line1, line2, line3], loc='best')
axarr[0].set_title('N = 10')

axarr[1].plot(x2, u2, x2, v2, x2, v22)
axarr[1].set_title('N = 100')

axarr[2].plot(x3, u3, x3, v3, x3, v32)
axarr[2].set_title('N = 1000')

plt.show()

# %%
# Out:
# [0.0, 0.472737, 0.612506, 0.618127, 0.5697, 0.499497, 0.420522, 0.338012, 0.254078, 0.169571, 0.0848319, 0.0]
